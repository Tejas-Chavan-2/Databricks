# %%
print("Hi! Tejas")

# %%
# %sql
select * from information_schema.tables

# %% [markdown]
# # DB

# %% [markdown]
# ## Tejas

# %%
mydata =[(1,'Tejas'),(2,'Rajesh'),(3,'Ravi')]
myschema="id INT, name STRING"
df=spark.createDataFrame(mydata,schema=myschema)

# %%
df.display()

# %%
df.show(truncate=False)

# %%
x=df.head(2)
y=df.tail(2)
print(x)

# %%
df.show(1)

# %%
spark.conf.set("fs.azure.account.auth.type.datalakeradhik.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.datalakeradhik.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.datalakeradhik.dfs.core.windows.net", "1eb72c80-a314-46d2-9216-c64b1bcfcd29")
spark.conf.set("fs.azure.account.oauth2.client.secret.datalakeradhik.dfs.core.windows.net", "WmW8Q~z4xQfQE~V8SiSU.uw_ucKvCSArmt_hKaPV")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.datalakeradhik.dfs.core.windows.net", "https://login.microsoftonline.com/fc79759c-53c1-40f5-97a3-b0808007dbb5/oauth2/token")

# %%
dbutils.fs.ls("abfss://landing@adlsaccountfortejas.dfs.core.windows.net")
# List files in the mounted directory

# %% [markdown]
# # dbutils.widgets()

# %%
dbutils.widgets.text("name","Tejas")

# %%
var=dbutils.widgets.get("name")

# %%
print(var)

# %%
dbutils.secrets.list(scope="tejscope")

# %%
dbutils.secrets.get(scope="tejscope",key="tejsecrets")

# %% [markdown]
# # Data reading

# %%
df=spark.read.format("delta") \
.option("header",True) \
.option("inferSchema",True)\
.load("abfss://source@datalakeradhik.dfs.core.windows.net")

# %%
# %python
# Set the Spark configuration for the Azure Data Lake Storage account
spark.conf.set(
    "fs.azure.account.key.adlsaccountfortejas.dfs.core.windows.net",
    "adlskey"
)

# List files in the ADLS directory
dbutils.fs.ls("abfss://landing@adlsaccountfortejas.dfs.core.windows.net")

# %%
dbutils.secrets.list(scope="tejscope")

# %%
dbutils.secrets.get(scope="tejscope",key="adlskey")

# %%
df=spark.read.format("delta") \
.option("header",True) \
.option("inferSchema",True)\
.load("https://adlsaccountfortejas.blob.core.windows.net/landing/sales.csv")

# %%
df=spark.read.format("delta").load("https://adlsaccountfortejas.blob.core.windows.net/landing/sales.csv")

# %%
df = spark.read.format("csv").load("abfss://landing@adlsaccountfortejas.dfs.core.windows.net/sales.csv")
